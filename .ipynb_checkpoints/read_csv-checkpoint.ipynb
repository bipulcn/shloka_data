# %%
import numpy as np
import pandas as pd
from googletrans import Translator
import asyncio
import pandas as pd
from IPython.display import display, HTML

# %%
rd = pd.read_csv('csv/bhagavad_gita.csv')
print(rd.loc[1]['meaning_in_english'])
rd.head()
# Out:
#    Unnamed: 0          verse_number  \
# 0           0    Chapter 1, Verse 1
# 1           1    Chapter 1, Verse 2
# 2           2    Chapter 1, Verse 3
# 3           3  Chapter 1, Verse 4-6
# 4           4  Chapter 1, Verse 4-6
#
#                                    verse_in_sanskrit  \
# 0  धृतराष्ट्र उवाच |धर्मक्षेत्रे कुरुक्षेत्रे समव...
# 1  सञ्जय उवाच ।दृष्ट्वा तु पाण्डवानीकं व्यूढं दुर...
# 2  पश्यैतां पाण्डुपुत्राणामाचार्य महतीं चमूम् ।व्...
# 3  अत्र शूरा महेष्वासा भीमार्जुनसमा युधि  युयुधान...
# 4  अत्र शूरा महेष्वासा भीमार्जुनसमा युधि  युयुधान...
#
#                       sanskrit_verse_transliteration  \
# 0  dhṛitarāśhtra uvācha dharma-kṣhetre kuru-kṣhet...
# 1  sañjaya uvācha dṛiṣhṭvā tu pāṇḍavānīkaṁ vyūḍha...
# 2  paśhyaitāṁ pāṇḍu-putrāṇām āchārya mahatīṁ cham...
# 3  atra śhūrā maheṣhvāsā bhīmārjuna-samā yudhiyuy...
# 4  atra śhūrā maheṣhvāsā bhīmārjuna-samā yudhiyuy...
#
#                               translation_in_english  \
# ...

# %%
from googletrans import Translator

# Create translator object
translator = Translator()

# English text
text = "Sanjay understood Dhritarashtra’s concern, who wanted an assurance that the battle would eventuate. Sanjay tried to allay his worry by informing that the Pandava army was standing in a military formation, ready for battle. Then he moved on to tell him what his son Duryodhana was doing on the battlefield.As King Dhritarashtra was blind, his eldest son Duryodhana virtually ruled the kingdom of Hastinapur. In the Mahabharata, he is described as very rude, egoistic, evil and cruel by nature. Since his childhood, he had a strong dislike for the Pandavas and left no opportunity to demean them. He was aware that to rule over the entire kingdom of Hastinapur unchallenged he needed to eliminate them. However, standing on the battlefield, when he saw the large Pandava army, he was baffled. He had underestimated the Pandavas, the extent of military might they had gathered was way beyond his expectation.Duryodhana approached his guru Dronacharya with the pretense of offering respect, but his actual purpose was to palliate his own nervousness. His move towards his guru also reveals that the mammoth military formation of the Pandava army unnerved him and he was now fearful of the outcome of this war.The next nine verses are spoken by Duryodhan."

# Translate to Bangla
result = translator.translate(text, src='en', dest='bn')

# print("Original:", text)
print(result.text)
# Out:
# Original: Sanjay understood Dhritarashtra’s concern, who wanted an assurance that the battle would eventuate. Sanjay tried to allay his worry by informing that the Pandava army was standing in a military formation, ready for battle. Then he moved on to tell him what his son Duryodhana was doing on the battlefield.As King Dhritarashtra was blind, his eldest son Duryodhana virtually ruled the kingdom of Hastinapur. In the Mahabharata, he is described as very rude, egoistic, evil and cruel by nature. Since his childhood, he had a strong dislike for the Pandavas and left no opportunity to demean them. He was aware that to rule over the entire kingdom of Hastinapur unchallenged he needed to eliminate them. However, standing on the battlefield, when he saw the large Pandava army, he was baffled. He had underestimated the Pandavas, the extent of military might they had gathered was way beyond his expectation.Duryodhana approached his guru Dronacharya with the pretense of offering respect, b
# ...

# %%
rd = pd.read_csv('csv/bhagavad-gita.csv')
rd.head()
# Out:
#    Unnamed: 0  title                                         devanagari  \
# 0           0    1.1  धृतराष्ट्र उवाच ।\r\nधर्मक्षेत्रे कुरुक्षेत्रे...
# 1           1    1.2  सञ्जय उवाच ।\r\nदृष्ट्वा तु पाण्डवानीकं व्यूढं...
# 2           2    1.3  पश्यैतां पाण्डुपुत्राणामाचार्य महतीं चमूम् ।\r...
# 3           3    1.4  अत्र शूरा महेष्वासा भीमार्जुनसमा युधि ।\r\nयुय...
# 4           4    1.5  धृष्टकेतुश्चेकितानः काशिराजश्च वीर्यवान् ।\r\n...
#
#                                           verse_text  \
# 0  dhṛtarāṣṭra uvāca\r\ndharma-kṣetre kuru-kṣetre...
# 1  sañjaya uvāca\r\ndṛṣṭvā tu pāṇḍavānīkaṁ\r\nvyū...
# 2  paśyaitāṁ pāṇḍu-putrānām\r\nācārya mahatīṁ cam...
# 3  atra śūrā maheṣv-āsā\r\nbhīmārjuna-samā yudhi\...
# 4  dhṛṣṭaketuś cekitānaḥ\r\nkāśirājaś ca vīryavān...
#
#                                verse_text_no_samdhis
# 0  dhṛtarāṣṭraḥ uvāca dharma kṣetre kuru kṣetre s...
# 1  sañjayaḥ uvāca dṛṣṭvā tu pāṇḍava anīkam vyūḍha...
# ...

# %%
rd = pd.read_csv('csv/Bhagwad_Gita.csv')
rd.head()
# Out:
#       ID  Chapter  Verse                                             Shloka  \
# 0  BG1.1        1      1  धृतराष्ट्र उवाच |\nधर्मक्षेत्रे कुरुक्षेत्रे स...
# 1  BG1.2        1      2  सञ्जय उवाच |\nदृष्ट्वा तु पाण्डवानीकं व्यूढं द...
# 2  BG1.3        1      3  पश्यैतां पाण्डुपुत्राणामाचार्य महतीं चमूम् |\n...
# 3  BG1.4        1      4  अत्र शूरा महेष्वासा भीमार्जुनसमा युधि |\nयुयुध...
# 4  BG1.5        1      5  धृष्टकेतुश्चेकितानः काशिराजश्च वीर्यवान् |\nपु...
#
#                                      Transliteration  \
# 0  dhṛtarāṣṭra uvāca .\ndharmakṣetre kurukṣetre s...
# 1  sañjaya uvāca .\ndṛṣṭvā tu pāṇḍavānīkaṃ vyūḍha...
# 2  paśyaitāṃ pāṇḍuputrāṇāmācārya mahatīṃ camūm .\...
# 3  atra śūrā maheṣvāsā bhīmārjunasamā yudhi .\nyu...
# 4  dhṛṣṭaketuścekitānaḥ kāśirājaśca vīryavān .\np...
#
#                                           HinMeaning  \
# 0  ।।1.1।।धृतराष्ट्र ने कहा -- हे संजय ! धर्मभूमि...
# 1  ।।1.2।।संजय ने कहा -- पाण्डव-सैन्य की व्यूह रच...
# ...

# %%
rd = pd.read_csv('csv/ramayana_shloka_dataset.csv')
rd.head()
# Out:
#    Unnamed: 0 kanda_name  sarga verse_ref  \
# 0           0       Bala      1     १-१-१
# 1           1       Bala      1     १-१-२
# 2           2       Bala      1     १-१-३
# 3           3       Bala      1     १-१-४
# 4           4       Bala      1     १-१-५
#
#                                               shloka  \
# 0  तपःस्वाध्यायनिरतं तपस्वी वाग्विदां वरम् |\nनार...
# 1  को न्वस्मिन् साम्प्रतं लोके गुणवान् कश्च वीर्य...
# 2  चारित्रेण च को युक्तः सर्वभूतेषु को हितः |\nवि...
# 3  आत्मवान् को जितक्रोधो  द्युतिमान् कोऽनसूयकः |\...
# 4  एतदिच्छाम्यहं श्रोतुं परं कौतूहलं हि मे |\nमहर...
#
#                                          translation
# 0  The ascetic Valmiki inquired Naarada - 'who en...
# 1  "Who really is that person in this present wor...
# 2  "Who is appropriate in disposition... who is i...
# 3  "Who is that self-composed one, who controlled...
# 4  "All this I wish to listen from you, oh! Great...

# %%
rd = pd.read_csv('csv/sanskrit_data.csv')
rd.head()
# Out:
#                                                 text  \
# 0   दोपाध्याय, असम् १ उमा उषा सीता लक्ष्मीः गङ्गा...
# 1  का गोविन्दः, तिरुपति गृहे गृहे पातयतीव नित्यं ...
# 2  साहाय्यार्थ कोविसंकटसमये चलचित्रनटः यश्वर्येण ...
# 3  राष्ट्र श्री देवालय सन्दर्शयित्वा विशेषपूर्ण त...
# 4  भिन्नं चलिते गुजरातस्य चर्चा मतं वर्षे भवति तम...
#
#                                              summary
# 0                         स्मरणयोग्यम् नामपञ्चकम् ।
# 1                    प्रहेलिका का गोविन्दः, तिरुपति
# 2  चित्ररङ्गस्य बेङ्गळूरु कर्मकराणां साहाय्यम्  य...
# 3                                        यू राष्ट्र
# 4     कृते अकालनिर्वाचनं गुजरातराज्यस्य संभाव्यते ।

# %%
rd = pd.read_csv('csv/vidur nity.csv')
rd.head()
# Out:
#                                                Sloka              Class
# 0  यो यस्मिन् कर्माणि कुशलस्तं तस्मित्रैव योजयेत्...    sanskrit-slogan
# 1           अध्ययनेन/अध्ययनं वीना ज्ञानं न भवति ॥       sanskrit-slogan
# 2  पुष्पं पुष्पं विचिन्वीत मूलच्छेदं न कारयेत् । ...  Vidur Niti Slokas
# 3                           मृजया रक्ष्यते रूपम् ॥      sanskrit-slogan
# 4  मूर्खश्चिरायुर्जातोऽपि तस्माज्जातमृतो वरः।    ...    Chanakya Slokas

# %%
rd = pd.read_csv('csv/vidur nitys.csv')
rd.head()
# Out:
#                                                Sloka              Class
# 0  यस्मात् त्रस्यन्ति भूतानि मृगव्याधान्मृगा इव। ...  Vidur Niti Slokas
# 1  एतान्यनिगृहीतानि  व्यापादयितुमप्यलम्।         ...  Vidur Niti Slokas
# 2   यावत्स्वस्थो ह्यय देहः तावन्मृत्युश्च दूरतः। ...    Chanakya Slokas
# 3   ईश्वरस्य  स्मरणं प्रभाते उत्थाय अवश्यं  कर्तं...    sanskrit-slogan
# 4   लोकयात्रा भयं लज्जा दाक्षिण्यं त्यागशीलता।   ...    Chanakya Slokas

# %%
rd = pd.read_csv('csv/word-meaning.csv')
rd.head()
# Out:
#    Index category                                        description  nagari  \
# 0      0    grass  a grass (Eleusine indica) used for sacrificial...   बल्बज
# 1      1    grass                                the name of a grass    दर्भ
# 2      2    grass              a species of grass (Panicum dactylon)  दूर्वा
# 3      3    grass  fodder, especially for the horse victim of the...     घास
# 4      4    grass     a stalk of reed grass, often denotes fragility   इषीका
#
#      word
# 0  balbaj
# 1   darbh
# 2   durva
# 3    ghas
# 4  ishika

# %%
js = pd.read_json('csv/corrected_translation_gpt3.json')
print(js.shape)
js.head()
# Out:
# (4907, 8)
#             authorName  author_id  \
# 0     Swami Ramsukhdas          1
# 1  Swami Tejomayananda         17
# 2   Swami Adidevananda         18
# 3   Swami Gambirananda         19
# 4      Swami Sivananda         16
#
#                                          description  id     lang  \
# 0  ।।1.1।। धृतराष्ट्र बोले (टिप्पणी प0 1.2) - हे ...   1    hindi
# 1  \n\n।।1.1।।धृतराष्ट्र ने कहा -- हे संजय ! धर्म...   2    hindi
# 2  Dhṛtarāṣṭra said: “O Sanjaya, what did my peop...   3  english
# 3  \nDhṛtarāṣṭra said: O Sanjaya, what did my son...   4  english
# 4  \nDhritarashtra said, "What did my people and ...   5  english
#
#    language_id  verseNumber  verse_id
# 0            2            1         1
# 1            2            1         1
# 2            1            1         1
# 3            1            1         1
# 4            1            1         1

# %%
js = pd.read_json('csv/translation_old.json')
js.head(10)
# Out:
#               authorName  author_id  \
# 0       Swami Ramsukhdas          1
# 1    Swami Tejomayananda         17
# 2     Swami Adidevananda         18
# 3     Swami Gambirananda         19
# 4        Swami Sivananda         16
# 5  Dr. S. Sankaranarayan         20
# 6     Shri Purohit Swami         21
# 7       Swami Ramsukhdas          1
# 8    Swami Tejomayananda         17
# 9     Swami Adidevananda         18
#
#                                          description  id     lang  \
# 0  ।।1.1।। धृतराष्ट्र बोले (टिप्पणी प0 1.2) - हे ...   1    hindi
# 1  \n\n।।1.1।।धृतराष्ट्र ने कहा -- हे संजय ! धर्म...   2    hindi
# 2  1.1 Dhrtarastra said  On the holy field of Kur...   3  english
# 3  \n1.1. Dhrtarastra said  O Sanjaya, what did m...   4  english
# 4  1.1 Dhritarashtra said  What did my people and...   5  english
# 5  1.1. Dhrtarastra said  O Sanjaya ! What did my...   6  english
# 6  1.1 The King Dhritarashtra asked: "O Sanjaya! ...   7  english
# ...

# %%
js.shape
# Out:
# (4907, 8)
