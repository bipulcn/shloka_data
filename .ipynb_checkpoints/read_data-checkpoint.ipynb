# %%
import numpy as np
import pandas as pd
from googletrans import Translator
import asyncio
import pandas as pd
from IPython.display import display, HTML

# %%
dt = pd.read_json('data/chapters.json')
dt.head()
# Out:
#    chapter_number                                    chapter_summary  \
# 0               1  The first chapter of the Bhagavad Gita - "Arju...
# 1               2  The second chapter of the Bhagavad Gita is "Sa...
# 2               3  The third chapter of the Bhagavad Gita is "Kar...
# 3               4  The fourth chapter of the Bhagavad Gita is "Jn...
# 4               5  The fifth chapter of the Bhagavad Gita is "Kar...
#
#                                chapter_summary_hindi  id  \
# 0  भगवद गीता का पहला अध्याय अर्जुन विशाद योग उन प...   1
# 1  भगवद गीता का दूसरा अध्याय सांख्य योग है। यह अध...   2
# 2  भगवद गीता का तीसरा अध्याय कर्मयोग या निःस्वार्...   3
# 3  भगवद गीता का चौथा अध्याय ज्ञानकर्मसंन्यासयोग य...   4
# 4  भगवद गीता का पांचवा अध्याय कर्मसन्यासयोग योग ह...   5
#
#                  image_name                 name  \
# 0       arjuna-vishada-yoga       अर्जुनविषादयोग
# 1              sankhya-yoga            सांख्ययोग
# 2                karma-yoga              कर्मयोग
# ...

# %%
dt = pd.read_json('data/commentary.json')
dt.head(20)
# Out:
#                                authorName  author_id  \
# 0                        Swami Ramsukhdas          1
# 1                     Swami Chinmayananda          2
# 2                           Sri Anandgiri          3
# 3                            Sri Dhanpati          4
# 4                       Sri Madhavacharya          5
# 5                           Sri Neelkanth          6
# 6                      Sri Ramanujacharya          7
# 7                      Sri Sridhara Swami          8
# 8   Sri Vedantadeshikacharya Venkatanatha          9
# 9                        Sri Abhinavgupta         10
# 10                         Sri Jayatritha         11
# 11               Sri Madhusudan Saraswati         12
# 12                      Sri Purushottamji         13
# 13                     Sri Shankaracharya         14
# 14                     Sri Vallabhacharya         15
# 15                        Swami Sivananda         16
# 16                       Swami Ramsukhdas          1
# ...

# %%
dt = pd.read_json('data/verse.json')
dt.head()
# Out:
#    chapter_id  chapter_number  externalId  id  \
# 0           1               1           1   1
# 1           1               1           2   2
# 2           1               1           3   3
# 3           1               1           4   4
# 4           1               1           5   5
#
#                                                 text    title  verse_number  \
# 0  धृतराष्ट्र उवाच\n\nधर्मक्षेत्रे कुरुक्षेत्रे स...  Verse 1             1
# 1  सञ्जय उवाच\n\nदृष्ट्वा तु पाण्डवानीकं व्यूढं द...  Verse 2             2
# 2  पश्यैतां पाण्डुपुत्राणामाचार्य महतीं चमूम्।\n\...  Verse 3             3
# 3  अत्र शूरा महेष्वासा भीमार्जुनसमा युधि।\n\nयुयु...  Verse 4             4
# 4  धृष्टकेतुश्चेकितानः काशिराजश्च वीर्यवान्।\n\nप...  Verse 5             5
#
#    verse_order                                    transliteration  \
# 0            1  dhṛitarāśhtra uvācha\ndharma-kṣhetre kuru-kṣhe...
# 1            2  sañjaya uvācha\ndṛiṣhṭvā tu pāṇḍavānīkaṁ vyūḍh...
# ...

# %%
dt = pd.read_json('data/translation.json')
dt.head(20)
# Out:
#                authorName  author_id  \
# 0        Swami Ramsukhdas          1
# 1     Swami Tejomayananda         17
# 2      Swami Adidevananda         18
# 3      Swami Gambirananda         19
# 4         Swami Sivananda         16
# 5   Dr. S. Sankaranarayan         20
# 6      Shri Purohit Swami         21
# 7        Swami Ramsukhdas          1
# 8     Swami Tejomayananda         17
# 9      Swami Adidevananda         18
# 10     Swami Gambirananda         19
# 11        Swami Sivananda         16
# 12  Dr. S. Sankaranarayan         20
# 13     Shri Purohit Swami         21
# 14       Swami Ramsukhdas          1
# 15    Swami Tejomayananda         17
# 16     Swami Adidevananda         18
# 17     Swami Gambirananda         19
# 18        Swami Sivananda         16
# 19  Dr. S. Sankaranarayan         20
#
#                                           description  id     lang  \
# 0   ।।1.1।। धृतराष्ट्र बोले (टिप्पणी प0 1.2) - हे ...   1    hindi
# ...
